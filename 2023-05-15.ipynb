# %% [markdown]
# #### 2023-05-15

# %% [markdown]
# ##### 1교시

# %%
# BeautifulSoup에서 클래스만 선택해서 가져오는 메서드는?
find_all(), find(), select(), select_one()

# %%
# 가져온 글자가 깨졌을 때
decode(encoding = '__') : utf-8,cp949

# %%
# 크롤링

# %%
import urllib.request
from bs4  import BeautifulSoup
import pandas as pd

li = []
li1 = []
for i in range(1,6):
    url = 'https://www.pressian.com/pages/news-world-list?page='+str(i)
        
    html = urllib.request.urlopen(url).read().decode(encoding='utf-8')
    
    soup = BeautifulSoup(html, 'html.parser')
    
    titles = soup.find_all(class_ = "body" )
    for title  in titles:
        li.append(title.text)
        
    sub_titles = soup.find_all(class_ = "sub_title" )
    for sub_title  in sub_titles:
        li1.append(sub_title.text)    

df = pd.DataFrame({'소제목': li1, '첫줄':li})
df[:3]
# Out:
#                                                  소제목  \
# 0        경쟁자 클르츠다로을루, 부엌서 양파 들고 홍보 영상 '부드러운 이미지' 차별화
# 1  전진당, 제1당 올랐지만 실제 정부 구성 가능할지 미지수…군부 쿠데타 가능성 배제하...
# 2         실종자 600명 넘어 추가 피해 우려…부검 결과 구타·질식·장기 적출 사례도
#
#                                                   첫줄
# 0  14일(이하 현지시각) 치러진 튀르키예(터키) 대통령 선거 개표에서 20년 장기 집...
# 1  태국 총선에서 군부도 탁신도 아닌 제3의 세력이 승리하며 정치교체가 이뤄될 수 있을...
# 2  케냐에서 '예수를 만나려면 굶어 죽으라'는 주장을 펼친 것으로 알려진 사이비 종교 ...

# %%
li = []
li1 = []
for i in range(1,6):
    url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=fifty%20fifty&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=43&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all&start='+str(i)

        
    html = urllib.request.urlopen(url).read().decode(encoding='utf-8')
    
    soup = BeautifulSoup(html, 'html.parser')
    
    titles = soup.find_all(class_ = "news_tit" )
    for title  in titles:
        li.append(title.text)
        
    sub_titles = soup.find_all(class_ = "api_txt_lines dsc_txt_wrap" )
    for sub_title  in sub_titles:
        li1.append(sub_title.text)    

df = pd.DataFrame({'소제목': li1, '첫줄':li})
df[:3]
# Out:
#                                                  소제목  \
# 0  Fifty Fifty-music charts Fifty Fifty's 'Cupid'...
# 1  Fifty Fifty's "Cupid" landed at No. 19 on Bill...
# 2  그룹 피프티 피프티(FIFTY FIFTY)의 'CUPID'가 영국 '오피셜 싱글차트...
#
#                                                   첫줄
# 0  Fifty Fifty's 'Cupid' climbs to No. 8 on the B...
# 1  Fifty Fifty's 'Cupid' lands at No. 19 on Billb...
# 2                피프티 피프티, 'CUPID'로 쓴 新기록..英 오피셜차트 8위

# %%
from urllib.parse import quote_plus

# %%
import urllib.request
from bs4 import BeautifulSoup
from urllib.parse import quote
import pandas as pd

li = []
li1 = []

keyword = quote(input("입력값 = "))

for i in range(1,6):

    url = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query='+keyword+'&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=23&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all&start='+str(i)
 
    html = urllib.request.urlopen(url).read().decode(encoding='utf-8')
    
    soup = BeautifulSoup(html, 'html.parser')
    
    titles = soup.find_all(class_="news_tit")
    for title in titles:
        li.append(title.text)
    
    sub_titles = soup.find_all(class_="api_txt_lines dsc_txt_wrap")
    for sub_title in titles:
        li1.append(sub_title.text)
    
                       
df = pd.DataFrame({'소제목': li1, '첫줄': li})

df[:5]
# Out:
# 입력값 =  aa
#                                              소제목  \
# 0                프랑스 신용등급 떨어졌는데…마크롱 "감세 추진하고 싶다"
# 1                        회사채 옥석가리기 재개…AA급 우량채 출동
# 2  [더벨][CFO & Credit]이마트, AA+ 회복 언제…아쉬운 G마켓 '웃돈'
# 3           린나이, '착한 소비' 권장하는 'ONE FOR ONE' 프로모션
# 4  “착한 부채는 없다” 韓경제 ‘부채 역습’ 시작될까[추경, 빚의 복수 부르나...
#
#                                               첫줄
# 0                프랑스 신용등급 떨어졌는데…마크롱 "감세 추진하고 싶다"
# 1                        회사채 옥석가리기 재개…AA급 우량채 출동
# 2  [더벨][CFO & Credit]이마트, AA+ 회복 언제…아쉬운 G마켓 '웃돈'
# 3           린나이, '착한 소비' 권장하는 'ONE FOR ONE' 프로모션
# 4  “착한 부채는 없다” 韓경제 ‘부채 역습’ 시작될까[추경, 빚의 복수 부르나...

# %%
def crawl(search):
    for i in range(1,2):

        url = f'https://search.naver.com/search.naver?where=news&sm=tab_pge&query='+{search}+'&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=23&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all&start='+str(i)

        html = urllib.request.urlopen(url).read().decode(encoding='utf-8')

        soup = BeautifulSoup(html, 'html.parser')

        titles = soup.find_all(class_="news_tit")
        for title in titles:
            li.append(title.text)

        sub_titles = soup.find_all(class_="news_dsc")
        for sub_title in titles:
            li1.append(sub_title.text)
    
                       
df = pd.DataFrame({'소제목': li1, '첫줄': li})

df[:5]
# Out:
#                                                  소제목  \
# 0  Fifty Fifty-music charts Fifty Fifty's 'Cupid'...
# 1  Fifty Fifty's "Cupid" landed at No. 19 on Bill...
# 2  그룹 피프티 피프티(FIFTY FIFTY)의 'CUPID'가 영국 '오피셜 싱글차트...
# 3  FIFTY FIFTY grabs No. 19 spot on Billboard Hot...
# 4  또 그가 신인 걸그룹 '피프티 피프티(FIFTY FIFTY)'의 '큐피드(Cupid...
#
#                                                   첫줄
# 0  Fifty Fifty's 'Cupid' climbs to No. 8 on the B...
# 1  Fifty Fifty's 'Cupid' lands at No. 19 on Billb...
# 2                피프티 피프티, 'CUPID'로 쓴 新기록..英 오피셜차트 8위
# 3  [INTERVIEW] FIFTY FIFTY's chief producer SIAHN...
# 4                           브루노 마스가 '하입 보이'와 '큐피드'를?

# %% [markdown]
# ##### 2교시

# %%
li = []
li1 = []
li2 = []
def crawl(search):
    search = quote_plus(search)
    for i in range(1,6):
        url = f'https://search.naver.com/search.naver?where=news&sm=tab_pge&query={search}&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=43&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all&start='+str(i)

        html = urllib.request.urlopen(url).read().decode(encoding='utf-8')

        soup = BeautifulSoup(html, 'html.parser')

        titles = soup.find_all(class_ = "news_tit" )
        for title  in titles:
            li.append(title.text)

        sub_titles = soup.find_all(class_ = "api_txt_lines dsc_txt_wrap" )
        for sub_title  in sub_titles:
            li1.append(sub_title.text)    
        
        for i in range(len(titles)):
            li2.append(titles[i].attrs['href'])
            
    df = pd.DataFrame({'소제목': li1, '첫줄':li, '링크':li2})
    return df

# %%
df[:3]
# Out:
#                                                  소제목  \
# 0  Fifty Fifty-music charts Fifty Fifty's 'Cupid'...
# 1  Fifty Fifty's "Cupid" landed at No. 19 on Bill...
# 2  그룹 피프티 피프티(FIFTY FIFTY)의 'CUPID'가 영국 '오피셜 싱글차트...
#
#                                                   첫줄
# 0  Fifty Fifty's 'Cupid' climbs to No. 8 on the B...
# 1  Fifty Fifty's 'Cupid' lands at No. 19 on Billb...
# 2                피프티 피프티, 'CUPID'로 쓴 新기록..英 오피셜차트 8위

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from requests) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from requests) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from requests) (3.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
li = []
li1 = []
li2 = []

for i in range(1,6):
    url = 'https://search.daum.net/search?w=news&q=%EC%9A%B0%ED%81%AC%EB%9D%BC%EC%9D%B4%EB%82%98&DA=PGD&spacing=0&p='+str(i)

    headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"}

    html = requests.get(url, headers = headers) #html 가져오기 

    soup = BeautifulSoup(html.text, 'html.parser')

    titles = soup.find_all(class_ = "tit_main fn_tit_u" )
    for title  in titles:
        li.append(title.text)

    sub_titles = soup.find_all(class_ = "desc" )
    for sub_title  in sub_titles:
        li1.append(sub_title.text)    

    for i in range(len(titles)):
        li2.append(titles[i].attrs['href'])

df = pd.DataFrame({'소제목': li, '첫줄':li1, '링크':li2})
df[:3]
# Out:
#                                  소제목  \
# 0  러시아, 바흐무트서 우크라이나 공격에 여단 지휘관 2명 전사
# 1  무더기 추락한 러시아 군용기, 아군 오사로 격추?…의문 증폭
# 2          젤렌스키 우크라이나 대통령, 프랑스 깜짝 방문
#
#                                                   첫줄  \
# 0  [바흐무트=AP/뉴시스] 12일(현지시각) 우크라이나 도네츠크주 격전지 바흐무트 인...
# 1  재판매 및 DB 금지. 2023.5.15 (서울=연합뉴스) 권수현 기자 = 러시아 ...
# 2  [파리=AP/뉴시스] 에마뉘엘 마크롱(왼쪽) 프랑스 대통령이 14일(현지시각) 파리...
#
#                                            링크
# 0  https://v.daum.net/v/20230514235753477?f=o
# 1  https://v.daum.net/v/20230515082235651?f=o
# 2  https://v.daum.net/v/20230515095900066?f=o

# %% [markdown]
# ##### 3교시 검색 이미지 저장하기

# %%
base_url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
plus_url = quote_plus(input('검색어:'))
url = base_url + plus_url
print(url)
# Out:
# 검색어: 사과
# https://search.naver.com/search.naver?where=image&sm=tab_jum&query=%EC%82%AC%EA%B3%BC

# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (4.9.1)
# Requirement already satisfied: trio~=0.17 in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from selenium) (0.10.2)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from selenium) (1.26.14)
# Requirement already satisfied: attrs>=19.2.0 in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: outcome in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: sniffio in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: async-generator>=1.9 in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: wsproto>=0.14 in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/sonsoohan/anaconda3/lib/python3.10/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
hyml = urllib.request.urlopen(url).read().decode(encoding='utf-8')
soup = BeautifulSoup(html, 'html.parser')
titles = soup.find_all(class_ = "_image_listImage" )
titles[0].img['src']

# %%
from selenium import webdriver
driver = webdriver.Chrome()
driver.get('https://www.google.com')

# %%
driver.close()

# %% [markdown]
# ##### 4교시

# %% [markdown]
# ##### 5교시

# %%
base_url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
plus_url = quote_plus(input('검색어:'))
url = base_url + plus_url
driver = webdriver.Chrome()
driver.get(url)
# Out:
# 검색어: 사과

# %%
html = requests.get(url).text
soup = BeautifulSoup(html, 'html.parser')

# %%
images =  soup.find_all(class_ = '_image_listImage')

# %%
# 알라딘 코드 
from urllib.request  import urlopen
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
from selenium import webdriver  # pip install selenium
import time
import requests 

# 파일을 읽어와서 리스트로 만듬
list_title = []
with open('무제.txt', encoding='utf-8-sig')as f: 
    lines = f.readlines()
    
for line in lines:
    list_title.append(line)
print(list_title)
# Out:
# ['세이노의 가르침\n', '각각의 계절\n', '도둑맞은 집중력\n', '모든 삶은 흐른다\n', '사장학개론\n', '나의 돈 많은 고등학교 친구\n', '내가 가진 것을 세상이 원하게 하라\n', '하늘과 바람과 별과 인간\n', '흔한 남매 13\n', '심심해서 그랬어\n', '주린이가 가장 알고 싶은 최다질문\n', '달러구트 꿈 백화점\n', '2030 축의 전환\n', '기억의 전쟁 ']

# %%
import os
os.getcwd()
os.chdir('/Users/sonsoohan/Downloads/수업자료')

# %%
# 크롤링 시작
driver  = webdriver.Chrome()
number = 1

'''
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36"}
res = requests.get(url, headers = headers )
res.raise_for_status()
'''

for title in list_title:   
    
    base_url = 'https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Book&SearchWord='
    plus_url = title
    url = base_url +quote_plus(plus_url)
    print(url)    
        
    driver.get(url)   
    time.sleep(1)
# Out:
# https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Book&SearchWord=%EC%84%B8%EC%9D%B4%EB%85%B8%EC%9D%98+%EA%B0%80%EB%A5%B4%EC%B9%A8%0A
# https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Book&SearchWord=%EA%B0%81%EA%B0%81%EC%9D%98+%EA%B3%84%EC%A0%88%0A
# https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Book&SearchWord=%EB%8F%84%EB%91%91%EB%A7%9E%EC%9D%80+%EC%A7%91%EC%A4%91%EB%A0%A5%0A
# https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Book&SearchWord=%EB%AA%A8%EB%93%A0+%EC%82%B6%EC%9D%80+%ED%9D%90%EB%A5%B8%EB%8B%A4%0A
# https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Book&SearchWord=%EC%82%AC%EC%9E%A5%ED%95%99%EA%B0%9C%EB%A1%A0%0A
# https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Book&SearchWord=%EB%82%98%EC%9D%98+%EB%8F%88+%EB%A7%8E%EC%9D%80+%EA%B3%A0%EB%93%B1%ED%95%99%EA%B5%90+%EC%B9%9C%EA%B5%AC%0A
# https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Book&SearchWord=%EB%82%B4%EA%B0%80+%EA%B0%80%EC%A7%84+%EA%B2%83%EC%9D%84+%EC%84%B8%EC%83%81%EC%9D%B4+%EC%9B%90%ED%95%98%EA%B2%8C+%ED%95%98%EB%9D%BC%0A
# https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Book&SearchWord=%ED%95%98%EB%8A%98%EA%B3%BC+%EB%B0%94%EB%9E%8C%EA%B3%BC+%EB%B3%84%EA%B3%BC+%EC%9D%B8%EA%B0%84%0A
# https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Book&SearchWord=%ED%9D%94%ED%95%9C+%EB%82%A8%EB%A7%A4+13%0A
# https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Book&SearchWord=%EC%8B%AC%EC%8B%AC%ED%95%B4%EC%84%9C+%EA%B7%B8%EB%9E%AC%EC%96%B4%0A
# https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Book&SearchWord=%EC%A3%BC%EB%A6%B0%EC%9D%B4%EA%B0%80+%EA%B0%80%EC%9E%A5+%EC%95%8C%EA%B3%A0+%EC%8B%B6%EC%9D%80+%EC%B5%9C%EB%8B%A4%EC%A7%88%EB%AC%B8%0A
# https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Book&SearchWord=%EB%8B%AC%EB%9F%AC%EA%B5%AC%ED%8A%B8+%EA%BF%88+%EB%B0%B1%ED%99%94%EC%A0%90%0A
# https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Book&SearchWord=2030+%EC%B6%95%EC%9D%98+%EC%A0%84%ED%99%98%0A
# https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Book&SearchWord=%EA%B8%B0%EC%96%B5%EC%9D%98+%EC%A0%84%EC%9F%81+

# %% [markdown]
# ##### 6교시

# %%
import os

if not os.path.exists('./images'):
    os.makedirs('./images')

keyword = 'best_'
number = 1

with urlopen(image_url) as f: 
    with open(f'./images/{keyword}{number}{plus_url}.jpg', 'wb') as h:
        img = f.read()
        h.write(img)
        
number += 1

# %%
list_title = []
with open("무제.txt", encoding='utf-8-sig') as f:    # \ufeff 가 붙는 것을 해결
    lines = f.readlines()
    for line in lines:
        line = line.rstrip("\n")
        list_title.append(line)
print(list_title)

driver  = webdriver.Chrome()
number = 1

for title in list_title:   
    
    base_url = 'https://www.aladin.co.kr/search/wsearchresult.aspx?SearchTarget=Book&SearchWord='
    plus_url = title
    url = base_url +quote_plus(plus_url)
    # print(url)    
        
    driver.get(url)   
    time.sleep(1)
        
    html = driver.page_source  #urlopen().read() 에 해당
    soup = BeautifulSoup(html, 'html.parser')

    page_1 = soup.find(class_ = 'bo3')   # 첫번째 것 한개만 가져욤  # bo3 일 지도 모른다    
    url_2 = page_1.attrs['href'] 


    driver.get(url_2)   
    time.sleep(1)    
    
    html = driver.page_source  #urlopen().read() 에 해당
    soup = BeautifulSoup(html, 'html.parser')
    
 
    
    page_2 = soup.find(class_ = 'c_front')
    image_url = page_2.img['src'] 
    print(image_url)   
    
      
    # 저장하기 
    keyword = 'best_'
    with urlopen(image_url) as f: 
            with open('./images/'+ keyword + str(number) + plus_url+ ".jpg", "wb") as h:  # 이미지는 binary
                img = f.read()
                h.write(img)       
            
    number += 1


    
driver.close()

### 끝  ######
# Out:
# ['세이노의 가르침', '각각의 계절', '도둑맞은 집중력', '모든 삶은 흐른다', '사장학개론', '나의 돈 많은 고등학교 친구', '내가 가진 것을 세상이 원하게 하라', '하늘과 바람과 별과 인간', '흔한 남매 13', '심심해서 그랬어', '주린이가 가장 알고 싶은 최다질문', '달러구트 꿈 백화점', '2030 축의 전환', '기억의 전쟁 ']
# https://image.aladin.co.kr/product/30929/51/cover500/s302832892_1.jpg
# https://image.aladin.co.kr/product/31599/26/cover500/8954692524_1.jpg
# https://image.aladin.co.kr/product/31559/97/cover500/k682832859_1.jpg
# https://image.aladin.co.kr/product/31381/47/cover500/k292832005_1.jpg
# https://image.aladin.co.kr/product/31325/1/cover500/k832832683_3.jpg
# https://image.aladin.co.kr/product/31515/53/cover500/k842832539_1.jpg
# https://image.aladin.co.kr/product/31495/23/cover500/k572832334_1.jpg
# https://image.aladin.co.kr/product/31600/84/cover500/k612833060_1.jpg
# https://image.aladin.co.kr/product/31527/55/cover500/k812832343_1.jpg
# https://image.aladin.co.kr/product/9/20/cover500/8985494651_1.gif
# https://image.aladin.co.kr/product/26004/14/cover500/k682737326_3.jpg
# https://image.aladin.co.kr/product/24512/70/cover500/k392630952_2.jpg
# https://image.aladin.co.kr/product/30516/90/cover500/k252830490_1.jpg
# https://image.aladin.co.kr/product/31362/6/cover500/k042832290_1.jpg

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chr
= 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%9C%A4%EC%84%9D%EC%97%B4&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=12&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all&start=11'+str(i)
        
    html = urllib.request.urlopen(url).read().decode(encoding='utf-8')
    
    soup = BeautifulSoup(html, 'html.parser')
    
    titles = soup.find_all(class_ = "news_tit" )
    for title  in titles:
        li.append(title.text)
        
    sub_titles = soup.find_all(class_ = "api_txt_lines dsc_txt_wrap" )
    for sub_title  in sub_titles:
        li1.append(sub_title.text)    

df = pd.DataFrame({'소제목': li1, '첫줄':li})
df
# Out:
#                                                   소제목  \
# 0   김어준 유튜브 출연…“강력대응” 더불어민주당을 탈당한 김남국(무소속·사진) 의원이 ...
# 1   시사위크=서예진 기자 윤석열 대통령이 오는 19~21일 2박 3일 일정으로 일본 히...
# 2   윤석열 대통령이 제42회 스승의 날을 맞아 현장 교원과 모교 은사인 손관식 선생님 ...
# 3   연합뉴스에 따르면 윤석열 대통령의 국정 수행 지지율이 3주 연속 상승했다는 여론조사...
# 4   윤석열 대통령이 휴일인 14일 서울 용산 어린이정원 내 어린이야구장에서 열린 202...
# 5   윤석열 대통령, 양극화 사회에서 정치 신인의 태생적 한계에서 출발 윤석열 대통령은 ...
# 6   일본 간사이 지역 동포들이 14일 윤석열 정부의 한일 관계 개선 정책을 지지하는 성...
# 7   윤석열 대통령이 휴일인 14일 서울 용산 어린이정원 내 어린이야구장에서 열린 202...
# 8   윤석열 대통령이 14일 서울 용산어린이정원 내 야구장에서 열린 2023 대통령실 초...
# 9   윤석열 대통령이 15일 서울 용산 대통령실 청사에서 열린 제42회 스승의 날 기념 ...
# 10  시사위크=서예진 기자 윤석열 대통령이 오는 19~21일 2박 3일 일정으로 일본 히...
# 11  윤석열 대통령이 제42회 스승의 날을 맞아 현장 교원과 모교 은사인 손관식 선생님 ...
# 12  연합뉴스에 따르면 윤석열 대통령의 국정 수행 지지율이 3주 연속 상승했다는 여론조사...
# 13  윤석열 대통령이 휴일인 14일 서울 용산 어린이정원 내 어린이야구장에서 열린 202...
# 14  윤석열 대통령, 양극화 사회에서 정치 신인의 태생적 한계에서 출발 윤석열 대통령은 ...
# 15  일본 간사이 지역 동포들이 14일 윤석열 정부의 한일 관계 개선 정책을 지지하는 성...
# 16  윤석열 대통령이 휴일인 14일 서울 용산 어린이정원 내 어린이야구장에서 열린 202...
# 17  윤석열 대통령이 14일 서울 용산어린이정원 내 야구장에서 열린 2023 대통령실 초...
# 18  윤석열 대통령이 15일 서울 용산 대통령실 청사에서 열린 제42회 스승의 날 기념 ...
# 19  마쓰카와 루이 참의원 의원 마쓰카와 자민당 외교부회 회장대리는 “‘김대중-오부치 선...
# 20  윤석열 대통령이 제42회 스승의 날을 맞아 현장 교원과 모교 은사인 손관식 선생님 ...
# 21  연합뉴스에 따르면 윤석열 대통령의 국정 수행 지지율이 3주 연속 상승했다는 여론조사...
# 22  윤석열 대통령이 휴일인 14일 서울 용산 어린이정원 내 어린이야구장에서 열린 202...
# 23  윤석열 대통령, 양극화 사회에서 정치 신인의 태생적 한계에서 출발 윤석열 대통령은 ...
# 24  일본 간사이 지역 동포들이 14일 윤석열 정부의 한일 관계 개선 정책을 지지하는 성...
# 25  윤석열 대통령이 휴일인 14일 서울 용산 어린이정원 내 어린이야구장에서 열린 202...
# 26  윤석열 대통령이 14일 서울 용산어린이정원 내 야구장에서 열린 2023 대통령실 초...
# 27  윤석열 대통령이 15일 서울 용산 대통령실 청사에서 열린 제42회 스승의 날 기념 ...
# 28  마쓰카와 루이 참의원 의원 마쓰카와 자민당 외교부회 회장대리는 “‘김대중-오부치 선...
# 29  '남탓'하는 윤석열 대통령, '내탓'하는 김동연 지사 윤석열 대통령은 1년 전에 문...
# 30  연합뉴스에 따르면 윤석열 대통령의 국정 수행 지지율이 3주 연속 상승했다는 여론조사...
# 31  윤석열 대통령이 휴일인 14일 서울 용산 어린이정원 내 어린이야구장에서 열린 202...
# 32  윤석열 대통령, 양극화 사회에서 정치 신인의 태생적 한계에서 출발 윤석열 대통령은 ...
# 33  일본 간사이 지역 동포들이 14일 윤석열 정부의 한일 관계 개선 정책을 지지하는 성...
# 34  윤석열 대통령이 휴일인 14일 서울 용산 어린이정원 내 어린이야구장에서 열린 202...
# 35  윤석열 대통령이 14일 서울 용산어린이정원 내 야구장에서 열린 2023 대통령실 초...
# 36  윤석열 대통령이 15일 서울 용산 대통령실 청사에서 열린 제42회 스승의 날 기념 ...
# 37  마쓰카와 루이 참의원 의원 마쓰카와 자민당 외교부회 회장대리는 “‘김대중-오부치 선...
# 38  '남탓'하는 윤석열 대통령, '내탓'하는 김동연 지사 윤석열 대통령은 1년 전에 문...
# 39  윤석열 대통령이 휴일인 14일 서울 용산 어린이정원 내 축구장에서 대통령실 초청 전...
# 40  대통령실 제공 윤석열 대통령의 지지율이 전반적으로 소폭 상승했다. 이웃하고 있는 일...
# 41  윤석열 대통령이 휴일인 14일 서울 용산 어린이정원 내 어린이야구장에서 열린 202...
# 42  윤석열 대통령, 양극화 사회에서 정치 신인의 태생적 한계에서 출발 윤석열 대통령은 ...
# 43  일본 간사이 지역 동포들이 14일 윤석열 정부의 한일 관계 개선 정책을 지지하는 성...
# 44  윤석열 대통령이 휴일인 14일 서울 용산 어린이정원 내 어린이야구장에서 열린 202...
# 45  윤석열 대통령이 14일 서울 용산어린이정원 내 야구장에서 열린 2023 대통령실 초...
# 46  윤석열 대통령이 15일 서울 용산 대통령실 청사에서 열린 제42회 스승의 날 기념 ...
# 47  마쓰카와 루이 참의원 의원 마쓰카와 자민당 외교부회 회장대리는 “‘김대중-오부치 선...
# 48  '남탓'하는 윤석열 대통령, '내탓'하는 김동연 지사 윤석열 대통령은 1년 전에 문...
# 49  윤석열 대통령이 휴일인 14일 서울 용산 어린이정원 내 축구장에서 대통령실 초청 전...
#
#                                                    첫줄
# 0        “윤석열 정부가 실정 덮으려고 의도적 기획”… 김남국, 이재명 대응 방식과...
# 1                     윤석열 대통령, 19~21일 히로시마 G7 정상회의 참석
# 2                            윤석열 대통령, 스승의 날 전한 감사 메시지
# 3   [국정운영 및 정당 지지율] 윤석열 '긍정' 2.2%p 상승…국민의힘 1.4%p↑ ...
# 4                              윤석열 대통령, 어린이 야구 선수들 격려
# 5             윤석열 정부 1년 "국민은 사회 통합-상식이 복원되는 국가를 원한다!"
# 6                일본 간사이 재일동포들 “윤석열 정부 한일 관계 개선 정책 지지”
# 7                            윤석열 대통령, 유소년야구에서 구심으로 변신
# 8                                    윤석열 대통령 '스트라이크!'
# 9                                        발언하는 윤석열 대통령
# 10                    윤석열 대통령, 19~21일 히로시마 G7 정상회의 참석
# 11                           윤석열 대통령, 스승의 날 전한 감사 메시지
# 12  [국정운영 및 정당 지지율] 윤석열 '긍정' 2.2%p 상승…국민의힘 1.4%p↑ ...
# 13                             윤석열 대통령, 어린이 야구 선수들 격려
# 14            윤석열 정부 1년 "국민은 사회 통합-상식이 복원되는 국가를 원한다!"
# 15               일본 간사이 재일동포들 “윤석열 정부 한일 관계 개선 정책 지지”
# 16                           윤석열 대통령, 유소년야구에서 구심으로 변신
# 17                                   윤석열 대통령 '스트라이크!'
# 18                                       발언하는 윤석열 대통령
# 19            윤석열·기시다 선언엔 과거 아닌 미래 담아야 [기시다·홍석현 특별대담]
# 20                           윤석열 대통령, 스승의 날 전한 감사 메시지
# 21  [국정운영 및 정당 지지율] 윤석열 '긍정' 2.2%p 상승…국민의힘 1.4%p↑ ...
# 22                             윤석열 대통령, 어린이 야구 선수들 격려
# 23            윤석열 정부 1년 "국민은 사회 통합-상식이 복원되는 국가를 원한다!"
# 24               일본 간사이 재일동포들 “윤석열 정부 한일 관계 개선 정책 지지”
# 25                           윤석열 대통령, 유소년야구에서 구심으로 변신
# 26                                   윤석열 대통령 '스트라이크!'
# 27                                       발언하는 윤석열 대통령
# 28            윤석열·기시다 선언엔 과거 아닌 미래 담아야 [기시다·홍석현 특별대담]
# 29                             윤석열 대통령이 전 정권에서 배워야할 점
# 30  [국정운영 및 정당 지지율] 윤석열 '긍정' 2.2%p 상승…국민의힘 1.4%p↑ ...
# 31                             윤석열 대통령, 어린이 야구 선수들 격려
# 32            윤석열 정부 1년 "국민은 사회 통합-상식이 복원되는 국가를 원한다!"
# 33               일본 간사이 재일동포들 “윤석열 정부 한일 관계 개선 정책 지지”
# 34                           윤석열 대통령, 유소년야구에서 구심으로 변신
# 35                                   윤석열 대통령 '스트라이크!'
# 36                                       발언하는 윤석열 대통령
# 37            윤석열·기시다 선언엔 과거 아닌 미래 담아야 [기시다·홍석현 특별대담]
# 38                             윤석열 대통령이 전 정권에서 배워야할 점
# 39                                  축구공에 사인하는 윤석열 대통령
# 40                      3주째 오른 윤석열 대통령 지지율…한일정상회담 긍정적
# 41                             윤석열 대통령, 어린이 야구 선수들 격려
# 42            윤석열 정부 1년 "국민은 사회 통합-상식이 복원되는 국가를 원한다!"
# 43               일본 간사이 재일동포들 “윤석열 정부 한일 관계 개선 정책 지지”
# 44                           윤석열 대통령, 유소년야구에서 구심으로 변신
# 45                                   윤석열 대통령 '스트라이크!'
# 46                                       발언하는 윤석열 대통령
# 47            윤석열·기시다 선언엔 과거 아닌 미래 담아야 [기시다·홍석현 특별대담]
# 48                             윤석열 대통령이 전 정권에서 배워야할 점
# 49                                  축구공에 사인하는 윤석열 대통령

# %%
li = []
li1 = []
for i in range(1,2):
    url = 'https://www.donga.com/news/search?query=%EC%9A%B0%ED%81%AC%EB%9D%BC%EC%9D%B4%EB%82%98&sorting=1&check_news=93&search_date=1&v1=&v2=&more=1'+str(i)
        
    html = urllib.request.urlopen(url).read().decode(encoding='utf-8')
    
    soup = BeautifulSoup(html, 'html.parser')
    
    titles = soup.find_all(class_ = "tit" )
    for title  in titles:
        li.append(title.text)
        
    sub_titles = soup.find_all(class_ = "txt" )
    for sub_title  in sub_titles:
        li1.append(sub_title.text)    

df = pd.DataFrame({'소제목': li1, '첫줄':li})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 18
#      15     for sub_title  in sub_titles:
#      16         li1.append(sub_title.text)
# ---> 18 df = pd.DataFrame({'소제목': li1, '첫줄':li})
#      19 df
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/internals/construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/internals/construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/internals/construction.py:666, in _extract_index(data)
#     664 lengths = list(set(raw_lengths))
#     665 if len(lengths) > 1:
# --> 666     raise ValueError("All arrays must be of the same length")
#     668 if have_dicts:
#     669     raise ValueError(
#     670         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     671     )
#
# ValueError: All arrays must be of the same length
